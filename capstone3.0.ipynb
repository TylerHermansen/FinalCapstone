# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pitch = pd.concat(map(pd.read_csv,['pitch_speed.csv','pitch_arsenals.csv','pitch-arsenal-stats.csv']),
                  ignore_index=True)

# %%
pitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1720 entries, 0 to 1719
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   last_name          1720 non-null   object
#  1    first_name        1720 non-null   object
#  2   pitcher            1005 non-null   float64
#  3   ff_avg_speed       473 non-null    float64
#  4   si_avg_speed       331 non-null    float64
#  5   fc_avg_speed       152 non-null    float64
#  6   sl_avg_speed       424 non-null    float64
#  7   ch_avg_speed       388 non-null    float64
#  8   cu_avg_speed       305 non-null    float64
#  9   fs_avg_speed       40 non-null     float64
#  10  kn_avg_speed       0 non-null      float64
#  11  ff_avg_spin        466 non-null    float64
#  12  si_avg_spin        321 non-null    float64
#  13  fc_avg_spin        151 non-null    float64
#  14  sl_avg_spin        416 non-null    float64
# ...

# %%
pitch['player_name'] = pitch[[' first_name','last_name']].agg(' '.join, axis=1)

# %%
pitch.drop(
    columns=['last_name', ' first_name','pitcher','est_ba', 'est_slg', 'est_woba','kn_avg_speed','kn_avg_spin'],
    axis=1, inplace=True)

# %%
pitch.set_index(['player_name'], inplace=True)

# %%
pitch
# Out:
#                   ff_avg_speed  si_avg_speed  fc_avg_speed  sl_avg_speed  \
# player_name
#  Sandy Alcantara          97.9          97.6           NaN          89.6
#  Miles Mikolas            93.4          92.8           NaN          87.8
#  Aaron Nola               92.8          92.1          86.8           NaN
#  Dylan Cease              96.8          96.5           NaN          87.1
#  Gerrit Cole              97.8           NaN          92.1          88.4
# ...                        ...           ...           ...           ...
#  Adrian Houser             NaN           NaN           NaN           NaN
#  Chase De Jong             NaN           NaN           NaN           NaN
#  Joely Rodríguez           NaN           NaN           NaN           NaN
#  Jason Adam                NaN           NaN           NaN           NaN
#  JT Brubaker               NaN           NaN           NaN           NaN
#
#                   ch_avg_speed  cu_avg_speed  fs_avg_speed  ff_avg_spin  \
# ...

# %%
pitch.isnull().sum()
# Out:
# ff_avg_speed         1247
# si_avg_speed         1389
# fc_avg_speed         1568
# sl_avg_speed         1296
# ch_avg_speed         1332
# cu_avg_speed         1415
# fs_avg_speed         1680
# ff_avg_spin          1254
# si_avg_spin          1399
# fc_avg_spin          1569
# sl_avg_spin          1304
# ch_avg_spin          1339
# cu_avg_spin          1420
# fs_avg_spin          1681
# player_id            1005
# team_name_alt        1005
# pitch_type           1005
# pitch_name           1005
# run_value_per_100    1005
# run_value            1005
# pitches              1005
# pitch_usage          1005
# pa                   1005
# ba                   1005
# slg                  1005
# woba                 1005
# whiff_percent        1005
# k_percent            1005
# put_away             1005
# hard_hit_percent     1005
# dtype: int64

# %%
pitch.query('player_name == " Gerrit Cole"')
# Out:
# Empty DataFrame
# Columns: [ff_avg_speed, si_avg_speed, fc_avg_speed, sl_avg_speed, ch_avg_speed, cu_avg_speed, fs_avg_speed, ff_avg_spin, si_avg_spin, fc_avg_spin, sl_avg_spin, ch_avg_spin, cu_avg_spin, fs_avg_spin, player_id, team_name_alt, pitch_type, pitch_name, run_value_per_100, run_value, pitches, pitch_usage, pa, ba, slg, woba, whiff_percent, k_percent, put_away, hard_hit_percent]
# Index: []
#
# [0 rows x 30 columns]
