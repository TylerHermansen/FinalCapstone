# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pitch_speed = pd.read_csv('pitch_speed.csv')

# %%
pitch_spin = pd.read_csv('pitch_arsenals.csv')

# %%
pitch_ba = pd.read_csv('pitch-arsenal-stats.csv')

# %%
pitch_speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   last_name     507 non-null    object
#  1    first_name   507 non-null    object
#  2   pitcher       507 non-null    int64
#  3   ff_avg_speed  473 non-null    float64
#  4   si_avg_speed  331 non-null    float64
#  5   fc_avg_speed  152 non-null    float64
#  6   sl_avg_speed  424 non-null    float64
#  7   ch_avg_speed  388 non-null    float64
#  8   cu_avg_speed  305 non-null    float64
#  9   fs_avg_speed  40 non-null     float64
#  10  kn_avg_speed  0 non-null      float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 43.7+ KB

# %%
pitch_speed['player_name'] = pitch_speed[[' first_name','last_name']].agg(' '.join, axis=1)

# %%
pitch_speed.drop(columns=['last_name', ' first_name','pitcher'], axis=1, inplace=True)

# %%
pitch_speed
# Out:
#      ff_avg_speed  si_avg_speed  fc_avg_speed  sl_avg_speed  ch_avg_speed  \
# 0            97.9          97.6           NaN          89.6          91.8
# 1            93.4          92.8           NaN          87.8          82.5
# 2            92.8          92.1          86.8           NaN          85.9
# 3            96.8          96.5           NaN          87.1          77.7
# 4            97.8           NaN          92.1          88.4          89.9
# ..            ...           ...           ...           ...           ...
# 502           NaN          88.5          86.2          76.9           NaN
# 503          94.8          95.5           NaN          84.4          87.3
# 504          95.4           NaN           NaN          82.2           NaN
# 505          95.5          95.2          91.1           NaN          86.8
# 506          91.1          90.1           NaN          81.5          83.2
#
#      cu_avg_speed  fs_avg_speed  kn_avg_speed       player_name
# ...

# %%
pitch_spin
# Out:
#      last_name  first_name  pitcher  ff_avg_spin  si_avg_spin  fc_avg_spin  \
# 0    Alcantara       Sandy   645261       2174.0       2272.0          NaN
# 1         Nola       Aaron   605400       2280.0       2174.0       2165.0
# 2      Mikolas       Miles   571945       2301.0       2239.0          NaN
# 3        Cease       Dylan   656302       2504.0       2492.0          NaN
# 4      Gilbert       Logan   669302       2132.0          NaN          NaN
# ..         ...         ...      ...          ...          ...          ...
# 493      Mills       Wyatt   670090       1988.0       1810.0          NaN
# 494     Bruihl      Justin   677865          NaN       2156.0       2291.0
# 495      Weems      Jordan   607179       2095.0          NaN          NaN
# 496    Moronta       Reyes   606625       2312.0          NaN          NaN
# 497   Lawrence       Casey   596271       2230.0       2169.0          NaN
#
#      sl_avg_spin  ch_avg_spin  cu_avg_spin  fs_avg_spin  kn_avg_spin
# ...

# %%
pitch_spin['player_name'] = pitch_spin[[' first_name','last_name']].agg(' '.join, axis=1)

# %%
pitch_spin.drop(columns=['last_name', ' first_name','pitcher'], axis=1, inplace=True)

# %%
pitch_spin
# Out:
#      ff_avg_spin  si_avg_spin  fc_avg_spin  sl_avg_spin  ch_avg_spin  \
# 0         2174.0       2272.0          NaN       2334.0       2038.0
# 1         2280.0       2174.0       2165.0          NaN       1465.0
# 2         2301.0       2239.0          NaN       2409.0       1575.0
# 3         2504.0       2492.0          NaN       2845.0       1707.0
# 4         2132.0          NaN          NaN       2305.0       1717.0
# ..           ...          ...          ...          ...          ...
# 493       1988.0       1810.0          NaN       2384.0          NaN
# 494          NaN       2156.0       2291.0       2388.0          NaN
# 495       2095.0          NaN          NaN       2246.0        908.0
# 496       2312.0          NaN          NaN       2460.0       1947.0
# 497       2230.0       2169.0          NaN       2465.0       1781.0
#
#      cu_avg_spin  fs_avg_spin  kn_avg_spin       player_name
# 0         2333.0          NaN          NaN   Sandy Alcantara
# ...

# %%
pitch_ba
# Out:
#     pitch_name  run_value_per_100  run_value  pitches  pitch_usage   pa  \
# 0     4-Seamer               -1.5        -16     1077         62.1  267
# 1     4-Seamer               -0.5         -6     1023         55.7  261
# 2       Sinker               -0.2         -1      983         62.5  257
# 3       Cutter               -2.1        -22     1032         56.7  250
# 4     4-Seamer               -0.8         -7      884         58.9  227
# ..         ...                ...        ...      ...          ...  ...
# 710   4-Seamer                1.3          3      225         16.6   50
# 711     Slider               -2.6         -5      176         30.3   50
# 712   Changeup               -0.7         -1      174         37.0   50
# 713   Changeup               -2.5         -4      181         32.3   50
# 714  Curveball               -0.6         -1      227         14.6   50
#
#         ba    slg   woba  whiff_percent  k_percent  put_away  est_ba  est_slg  \
# ...

# %%
pitch_ba['player_name'] = pitch_ba[[' first_name','last_name']].agg(' '.join, axis=1)

# %%
pitch_ba.drop(columns=['last_name', ' first_name','player_id','pitch_type','team_name_alt'], axis=1, inplace=True)

# %%
pitch_ba
# Out:
#     pitch_name  run_value_per_100  run_value  pitches  pitch_usage   pa  \
# 0     4-Seamer               -1.5        -16     1077         62.1  267
# 1     4-Seamer               -0.5         -6     1023         55.7  261
# 2       Sinker               -0.2         -1      983         62.5  257
# 3       Cutter               -2.1        -22     1032         56.7  250
# 4     4-Seamer               -0.8         -7      884         58.9  227
# ..         ...                ...        ...      ...          ...  ...
# 710   4-Seamer                1.3          3      225         16.6   50
# 711     Slider               -2.6         -5      176         30.3   50
# 712   Changeup               -0.7         -1      174         37.0   50
# 713   Changeup               -2.5         -4      181         32.3   50
# 714  Curveball               -0.6         -1      227         14.6   50
#
#         ba    slg   woba  whiff_percent  k_percent  put_away  est_ba  est_slg  \
# ...
